# %%
from IPython.display import Image
Image("subarray_printscreen.jpg", width=850)

# %%
import collections

def subarraySum( nums, k):
    d = collections.defaultdict(int)
    d[0] = 1
    sum = 0;res = 0
    for i in range(len(nums)):
        sum += nums[i]
        print("Sum:"+str(sum))
        if sum - k in d:
            print(str(sum - k))
            res += d[sum - k]
            print("res:"+str(res))
        d[sum] += 1
        print("d[sum]:"+str(d[sum]))
        print('-------')
    return res

# %%
nums = [1,1,1,2,1,2,1]
k=3

subarraySum(nums,k)
# Out:
# Sum:1
# d[sum]:1
# -------
# Sum:2
# d[sum]:1
# -------
# Sum:3
# 0
# res:1
# d[sum]:1
# -------
# Sum:5
# 2
# res:2
# d[sum]:1
# -------
# Sum:6
# 3
# res:3
# d[sum]:1
# -------
# Sum:8
# 5
# res:4
# d[sum]:1
# -------
# Sum:9
# 6
# res:5
# d[sum]:1
# -------
# 5

# %%
from IPython.display import Image
Image("Subarray.jpg", width=850)
