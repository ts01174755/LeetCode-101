# %% [markdown]
# # 210. Course Schedule II

# %% [markdown]
# There are a total of n courses you have to take labelled from 0 to n - 1.
#
# Some courses may have prerequisites, for example, if prerequisites[i] = [ai, bi] this means you must take the course bi before the course ai.
#
# Given the total number of courses numCourses and a list of the prerequisite pairs, return the ordering of courses you should take to finish all courses.
#
# If there are many valid answers, return any of them. If it is impossible to finish all courses, return an empty array.

# %%
from IPython.display import Image
Image("./Image/210-Example.png", width=1000)

# %% [markdown]
# ## Solution

# %% [markdown]
# ## 核心概念
#
# "欲修 a 課程，得先修 bi 課程；當所有 bi 課程修習完成，得以修習 ai 課程" -> "對於沒有入邊的點 bi，拔除其出邊"

# %%
class Solution:
    def findOrder(self, numCourses: int, prerequisites: List[List[int]]) -> List[int]:
        degree = [0] * numCourses
        course_adj = [[] for _ in range(numCourses)]
        
        for course_ in prerequisites:
            c2, c1 = course_
            course_adj[c1].append(c2)
            degree[c2] +=1 
        ans = [i for i,v in enumerate(degree) if v == 0]

        for r_ in ans:
            for c_ in course_adj[r_]:
                degree[c_] -= 1
                if degree[c_] == 0:
                    ans.append(c_)
        return ans if len(ans) == numCourses else []

# %%
from IPython.display import Image
Image("./Image/210-Submission.png", width=1000)
