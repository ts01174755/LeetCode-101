# %% [markdown]
# # 399. Evaluate Division

# %% [markdown]
# You are given an array of variable pairs equations and an array of real numbers values, where equations[i] = [Ai, Bi] and values[i] represent the equation Ai / Bi = values[i]. Each Ai or Bi is a string that represents a single variable.
#
# You are also given some queries, where queries[j] = [Cj, Dj] represents the jth query where you must find the answer for Cj / Dj = ?.
#
# Return the answers to all queries. If a single answer cannot be determined, return -1.0.
#
# Note: The input is always valid. You may assume that evaluating the queries will not result in division by zero and that there is no contradiction.

# %%
from IPython.display import Image
Image("./Image/399-Example.png", width=1000)

# %% [markdown]
# ## Solution

# %%
class Solution:
    def calcEquation(self, equations: List[List[str]], values: List[float], queries: List[List[str]]) -> List[float]:
        graph = defaultdict(list)
        for i,eq in enumerate(equations):
            graph[eq[0]].append((eq[1],values[i]))
            graph[eq[1]].append((eq[0],1 / values[i]))
        
        ans = []
        for src,dst in queries:
            self.ans = None
            self.evaluate(src,dst,set(),graph,1)
            if self.ans != None:
                ans.append(self.ans)
            else:
                ans.append(-1)
        return ans
    
    def evaluate(self,node,target,visited,graph,sub):
        if node == target and graph[node]:
            self.ans = sub
            return
        
        visited.add(node)
        
        for nodes,weight in graph[node]:
            if nodes not in visited:
                self.evaluate(nodes,target,visited,graph,sub * weight)
                
        #visited.remove(node)

# %%
from IPython.display import Image
Image("./Image/399-Submission.png", width=1000)

# %% [markdown]
# # 心得

# %% [markdown]
# DFS 的過程將資訊帶往下一個節點
