# %% [markdown]
# # 207. Course Schedule

# %% [markdown]
# There are a total of numCourses courses you have to take, labeled from 0 to numCourses - 1. You are given an array prerequisites where prerequisites[i] = [ai, bi] indicates that you must take course bi first if you want to take course ai.
#
# For example, the pair [0, 1], indicates that to take course 0 you have to first take course 1.
# Return true if you can finish all courses. Otherwise, return false.

# %%
from IPython.display import Image
Image("./Image/207-Example.png", width=1000)

# %% [markdown]
# ## Terrible - Solution

# %%
from collections import defaultdict
class Solution:
    def canFinish(self, numCourses: int, prerequisites: List[List[int]]) -> bool:
        def dfs_cycle(i,graph,flag):
            for adj in graph[i]:
                if flag[adj] == 1: #adj is ancestor of i and child of i
                    return True
                if flag[adj] == -1:
                    continue
                flag[adj] = 1
                
                if dfs_cycle(adj,graph,flag):
                    return True
            flag[i] = -1 #out of stack
            return False
        
        graph = defaultdict(list)
        for x,y in prerequisites:
            graph[x].append(y)
        #print(graph)
        
        flag = defaultdict(int)
        for i in range(numCourses):
            if flag[i] == 0:
                flag[i] = 1
                if dfs_cycle(i,graph,flag):# cycle found
                    #print(i)
                    return False
        return True

# %%
from IPython.display import Image
Image("./Image/207-Submission.png", width=1000)
