# %% [markdown]
# #### Define what is Linked-List
# * Reference: https://www.itread01.com/content/1545817204.html

# %%
from IPython.display import Image
Image("Linked List.jpg", width=850)

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

# %% [markdown]
# ## I/O on Linked-List

# %% [markdown]
# #### eval() method

# %%
x1=2
x2=3
for i in (1,2):
    print("---string---")
    print("x{}".format(i))
    print("---eval(string) = variable---")
    print(eval("x%i" % i))
# Out:
# ---string---
# x1
# ---eval(string) = variable---
# 2
# ---string---
# x2
# ---eval(string) = variable---
# 3

# %%
data_1 = [1,2,4]

# %% [markdown]
# #### transform array(ed)-list to linked-list

# %%
l1 = ListNode(data_1[0])
for i in range(1,len(data_1)):
    eval("l"+str(i)).next = globals()["l" + str(i+1)] = ListNode(data_1[i])

# %%
print(l1.val)
# Out:
# 1

# %%
print(l2.val)
# Out:
# 2

# %%
print(l3.val)
# Out:
# 4

# %%
print(l4.val)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-1faa5011dd11> in <module>
# ----> 1 print(l4.val)
#
# NameError: name 'l4' is not defined

# %% [markdown]
# #### Output

# %%
while l1:
    print(l1.val)
    l1 = l1.next
# Out:
# 1
# 2
# 4
